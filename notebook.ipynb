# %%
import sqlite3
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

from datetime import datetime
from tqdm import tqdm
import time

from IPython.display import display, Markdown

# %% [markdown]
# ## Phase 1: Introduction to SQL and Databases + Python Integration (Setup)
# ### Goal: Create the database, define all tables, and load data from CSVs.

# %%
# =============================================
# CLEAN RESTART CELL - Run this first to start fresh
# =============================================

# Step 1: Close any existing connection and delete old database
try:
    conn.close()
except:
    pass

if os.path.exists('database.db'):
    os.remove('database.db')
    print("✅ Old database.db deleted successfully!")
else:
    print("No existing database found. Starting fresh.")
# Out:
# ✅ Old database.db deleted successfully!

# %%
# Step 2: Create a new clean connection
conn = sqlite3.connect('database.db')
print("✅ New clean database created.")
# Out:
# ✅ New clean database created.

# %%
# conn (connection) = The pipe that connects your Python code to the database file.
# cursor = The pen you use to write SQL commands through that pipe.

# %%
# Step 3: Load the corrected schema
try:
    with open('schema.sql', 'r', encoding='utf-8') as f:
        schema_script = f.read()
    
    conn.executescript(schema_script)
    conn.commit()
    print("✅ Schema loaded successfully! All tables created.")
    
except Exception as e:
    print(f"❌ Error loading schema: {e}")
# Out:
# ✅ Schema loaded successfully! All tables created.

# %%
# Step 4: Verify tables
print("\n📋 Tables created:")
tables_df = pd.read_sql("SELECT name AS table_name FROM sqlite_master WHERE type='table' ORDER BY name;", conn)
print(tables_df)
# Out:
# 📋 Tables created:
#                table_name
# 0        course_exam_info
# 1             course_info
# 2          course_ratings
# 3               quiz_info
# 4      student_engagement
# 5            student_exam
# 6   student_hub_questions
# 7            student_info
# 8        student_learning
# 9       student_purchases
# 10        student_quizzes

# %%
# =============================================
# FINAL ROBUST CSV LOADING CELL
# Loads ALL data even with orphan records
# =============================================

print("🚀 Starting ROBUST CSV loading (foreign keys temporarily disabled)...\n")

# Step 1: Disable foreign key checks so orphans don't block loading
conn.execute("PRAGMA foreign_keys = OFF;")
conn.commit()
print("✅ Foreign key checks DISABLED (allowing orphan records)")

# Step 2: Load tables in logical parent → child order
load_order = [
    'course_info',
    'student_info',
    'course_exam_info',
    'quiz_info',
    'student_purchases',
    'student_learning',
    'student_engagement',
    'student_quizzes',
    'student_exam',
    'course_ratings',
    'student_hub_questions'
]

csv_files = [f"{table}.csv" for table in load_order]

for csv_file in csv_files:
    table_name = csv_file.replace('.csv', '')
    file_path = f'data/{csv_file}'
    
    try:
        df = pd.read_csv(file_path)
        
        # Automatically drop any extra columns that don't exist in the table
        table_info = pd.read_sql(f"PRAGMA table_info({table_name});", conn)
        table_columns = table_info['name'].tolist()
        extra_cols = [col for col in df.columns if col not in table_columns]
        if extra_cols:
            print(f"   ⚠️  {csv_file}: ignoring extra columns → {extra_cols}")
            df = df.drop(columns=extra_cols)
        
        # Load the data
        df.to_sql(table_name, conn, if_exists='append', index=False)
        print(f"✅ Loaded {len(df):,} rows → {table_name}")
        
    except FileNotFoundError:
        print(f"❌ File not found: {file_path}")
    except Exception as e:
        print(f"❌ Failed to load {csv_file}: {e}")

# Step 3: Re-enable foreign key checks
conn.execute("PRAGMA foreign_keys = ON;")
conn.commit()
print("\n✅ Foreign key checks RE-ENABLED")

print("\n🎉 ALL DATA LOADING COMPLETE!")
print("You can now run analytics queries even with orphan records.")

# Optional: Show row counts for every table
print("\n📊 Final row counts:")
for table in load_order:
    try:
        count = pd.read_sql(f"SELECT COUNT(*) as rows FROM {table}", conn).iloc[0,0]
        print(f"   {table:25} → {count:,} rows")
    except:
        print(f"   {table:25} → error checking count")
# Out:
# 🚀 Starting ROBUST CSV loading (foreign keys temporarily disabled)...
#
# ✅ Foreign key checks DISABLED (allowing orphan records)
# ✅ Loaded 46 rows → course_info
# ✅ Loaded 1,000 rows → student_info
# ✅ Loaded 156 rows → course_exam_info
# ✅ Loaded 1,000 rows → quiz_info
# ✅ Loaded 1,000 rows → student_purchases
# ✅ Loaded 1,000 rows → student_learning
# ✅ Loaded 1,000 rows → student_engagement
# ❌ Failed to load student_quizzes.csv: Execution failed
# ✅ Loaded 1,000 rows → student_exam
# ✅ Loaded 1,000 rows → course_ratings
# ✅ Loaded 827 rows → student_hub_questions
#
# ✅ Foreign key checks RE-ENABLED
#
# 🎉 ALL DATA LOADING COMPLETE!
# You can now run analytics queries even with orphan records.
#
# 📊 Final row counts:
#    course_info               → 46 rows
#    student_info              → 1,000 rows
#    course_exam_info          → 156 rows
#    quiz_info                 → 1,000 rows
#    student_purchases         → 1,000 rows
#    student_learning          → 1,000 rows
#    student_engagement        → 1,000 rows
#    student_quizzes           → 0 rows
#    student_exam              → 1,000 rows
#    course_ratings            → 1,000 rows
#    student_hub_questions     → 827 rows

# %% [markdown]
# - ON DELETE CASCADE mean is a rule you put on a Foreign Key that tells SQLite:
# “If I delete a row from the parent table, automatically delete all related rows ie orphan records, in this child table.”
# - ON DELETE RESTRICT     -- prevents deletion if related rows exist
# - Disable foreign key checks so orphans don't block loading
# conn.execute("PRAGMA foreign_keys = OFF;")

# %% [markdown]
# - student_quizzes table composite PRIMARY KEY
# - PRIMARY KEY (student_id, quiz_id, question_id, answer_id)
# This means no duplicate combinations of those 4 columns are allowed.
# Your CSV likely has:
#
# Duplicate rows (same student + quiz + question + answer answered multiple times), or
# Extra columns that don't exist in the table, or
# Null/empty values in one of the key columns.
#
# %%sql
# select sql from sqlite_master

# %%
# =============================================
# ULTRA-TOLERANT FIX FOR student_quizzes (Option C)
# =============================================

print("🔧 Applying ultra-tolerant fix for student_quizzes...\n")

# Drop the old table completely
conn.execute("DROP TABLE IF EXISTS student_quizzes;")
conn.commit()

# Create the simplest possible table
conn.execute("""
    CREATE TABLE student_quizzes (
        student_id     INTEGER,
        quiz_id        INTEGER,
        question_id    INTEGER,
        answer_id      INTEGER,
        attempt_date   TEXT,
        score          REAL,
        created_at     TEXT DEFAULT CURRENT_TIMESTAMP
    );
""")
conn.commit()
print("✅ Created ultra-simple student_quizzes table (no constraints)")

# Load the CSV with maximum tolerance
try:
    df = pd.read_csv('data/student_quizzes.csv')
    
    print(f"CSV loaded: {df.shape[0]:,} rows, {df.shape[1]} columns")
    print(f"CSV columns: {list(df.columns)}")
    
    # Keep only columns that make sense
    keep_cols = ['student_id', 'quiz_id', 'question_id', 'answer_id']
    if 'attempt_date' in df.columns:
        keep_cols.append('attempt_date')
    if 'score' in df.columns:
        keep_cols.append('score')
    
    df = df[keep_cols]
    
    # Remove exact duplicates
    original = len(df)
    df = df.drop_duplicates()
    if original > len(df):
        print(f"Removed {original - len(df):,} duplicate rows")
    
    # Load into database
    df.to_sql('student_quizzes', conn, if_exists='append', index=False)
    
    final_count = len(df)
    print(f"✅ Successfully loaded {final_count:,} rows into student_quizzes")
    
except Exception as e:
    print(f"❌ Error: {e}")

# Final check
try:
    count = pd.read_sql("SELECT COUNT(*) as count FROM student_quizzes", conn).iloc[0,0]
    print(f"\nFinal row count in student_quizzes: {count:,} rows")
except Exception as e:
    print(f"Could not count rows: {e}")
# Out:
# 🔧 Applying ultra-tolerant fix for student_quizzes...
#
# ✅ Created ultra-simple student_quizzes table (no constraints)
# CSV loaded: 1,000 rows, 4 columns
# CSV columns: ['student_id', 'quiz_id', 'question_id', 'answer_id']
# ✅ Successfully loaded 1,000 rows into student_quizzes
#
# Final row count in student_quizzes: 1,000 rows

# %%
count = pd.read_sql("SELECT COUNT(*) as row_count FROM student_quizzes", conn).iloc[0,0]
print(f"Final row count in student_quizzes: {count:,} rows")
# Out:
# Final row count in student_quizzes: 1,000 rows

# %% [markdown]
# Always double-check column names when writing SQL. You can check your exact column names anytime with
# pd.read_sql("PRAGMA table_info(student_purchases);", conn)

# %% [markdown]
# **Demonstrates**: Database creation, schema design, Python + SQLite integration, bulk data import.

# %% [markdown]
# ## Phase 2: Summarizing Data in SQL + Visualizations
# ### Goal: Compute key platform KPIs and identify high-level issues.

# %%
# -------------------------------------------------
# 1. Overall Platform KPIs
# -------------------------------------------------
print("📊 Starting Phase 2: Summarizing Data...\n")

# --------------------- Progress Bar for KPIs ---------------------
print("Calculating Overall KPIs...")
with tqdm(total=5, desc="KPI Progress") as pbar:

    # 1. Total Students
    total_students = pd.read_sql("SELECT COUNT(DISTINCT student_id) as count FROM student_info", conn).iloc[0,0]
    pbar.update(1)

    # 2. Total Courses
    total_courses = pd.read_sql("SELECT COUNT(DISTINCT course_id) as count FROM course_info", conn).iloc[0,0]
    pbar.update(1)

    # 3. Total Purchases & Revenue
    purchase_stats = pd.read_sql("""
        SELECT COUNT(*) as total_purchases, 
               ROUND(SUM(amount_paid), 2) as total_revenue 
        FROM student_purchases
    """, conn).iloc[0]
    pbar.update(1)

    # 4. Average Rating
    avg_rating = pd.read_sql("SELECT ROUND(AVG(course_rating), 2) as avg_rating FROM course_ratings", conn).iloc[0,0]
    pbar.update(1)

    # 5. Average Engagement Score
    avg_engagement = pd.read_sql("SELECT ROUND(AVG(engagement_score), 2) as avg_engagement FROM student_engagement", conn).iloc[0,0]
    pbar.update(1)

    time.sleep(0.5)  # small delay for visibility

print("\n✅ Overall Platform KPIs:")
kpi_df = pd.DataFrame({
    'Metric': ['Total Students', 'Total Courses', 'Total Purchases', 'Total Revenue', 'Avg Course Rating', 'Avg Engagement Score'],
    'Value': [total_students, total_courses, purchase_stats['total_purchases'], 
              purchase_stats['total_revenue'] or 0, avg_rating or 0, avg_engagement or 0]
})
print(kpi_df.to_string(index=False))
# Out:
# 📊 Starting Phase 2: Summarizing Data...
#
# Calculating Overall KPIs...
# KPI Progress: 100%|██████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  9.91it/s]
# ✅ Overall Platform KPIs:
#               Metric   Value
#       Total Students 1000.00
#        Total Courses   46.00
#      Total Purchases 1000.00
#        Total Revenue    0.00
#    Avg Course Rating    4.78
# Avg Engagement Score    0.00

# %%
# =============================================
# ADD campaign_purchase COLUMN DIRECTLY TO SQLITE TABLE
# =============================================

print("Adding campaign_purchase column to the database...\n")

# Step 1: Add the new column to the table
conn.execute("""
    ALTER TABLE student_purchases 
    ADD COLUMN campaign_purchase TEXT DEFAULT 'no_campaign';
""")
conn.commit()
print("✅ Column 'campaign_purchase' added to student_purchases table.")

# Step 2: Update the column with correct logic (fixed typo)
update_query = """
UPDATE student_purchases
SET campaign_purchase = CASE
    WHEN date_purchased BETWEEN '2022-01-17' AND '2022-01-28' THEN 'winter_sale_2022'
    WHEN date_purchased BETWEEN '2022-03-21' AND '2022-03-31' THEN 'spring_special_offer_2022'
    WHEN date_purchased BETWEEN '2022-05-20' AND '2022-06-01' THEN 'data_science_summer_campaign_2022'
    WHEN date_purchased BETWEEN '2022-07-18' AND '2022-07-29' THEN 'most_wanted_campaign'
    WHEN date_purchased = '2022-09-16' THEN 'platform_gamification'
    WHEN date_purchased BETWEEN '2022-09-19' AND '2022-09-30' THEN 'data_science_hero_campaign'
    ELSE 'no_campaign'
END;
"""

conn.execute(update_query)
conn.commit()

print("✅ campaign_purchase column successfully populated in the database!")

# Step 3: Verify the results
verification = pd.read_sql("""
    SELECT 
        campaign_purchase,
        COUNT(*) as purchase_count,
        ROUND(SUM(amount_paid), 2) as total_revenue
    FROM student_purchases 
    GROUP BY campaign_purchase 
    ORDER BY total_revenue DESC;
""", conn)

print("\n📊 Campaign Distribution in Database:")
print(verification)
# Out:
# Adding campaign_purchase column to the database...
#
# ✅ Column 'campaign_purchase' added to student_purchases table.
# ✅ campaign_purchase column successfully populated in the database!
#
# 📊 Campaign Distribution in Database:
#            campaign_purchase  purchase_count total_revenue
# 0           winter_sale_2022             179          None
# 1  spring_special_offer_2022             161          None
# 2                no_campaign             660          None

# %%
# -------------------------------------------------
# 2. Campaign distribution in student_purchases
# -------------------------------------------------
# --------------------- Progress Bar for Course Summary ---------------------

print("🚀 Campaign Performance Analysis (Volume-based)\n")

with tqdm(total=1, desc="Course Analysis") as pbar:
    
    campaign_stats = pd.read_sql("""
        SELECT 
            campaign_purchase,
            COUNT(*) AS num_purchases,
            COUNT(DISTINCT student_id) AS unique_buyers
        FROM student_purchases
        GROUP BY campaign_purchase
        ORDER BY num_purchases DESC;
    """, conn)
    
    print("📊 Campaign Performance Summary:")
    print(campaign_stats)
    pbar.update(1)
# Out:
# 🚀 Campaign Performance Analysis (Volume-based)
# Course Analysis: 100%|██████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 160.46it/s]
# 📊 Campaign Performance Summary:
#            campaign_purchase  num_purchases  unique_buyers
# 0                no_campaign            660            532
# 1           winter_sale_2022            179            179
# 2  spring_special_offer_2022            161            161

# %%
# 2. Visualizations
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Bar chart - Number of Purchases by Campaign (Fixed)
sns.barplot(
    data=campaign_stats, 
    x='num_purchases', 
    y='campaign_purchase', 
    hue='campaign_purchase',      # Fix: assign hue
    palette='viridis', 
    legend=False,                 # Fix: remove legend since y is the category
    ax=axes[0]
)
axes[0].set_title('Number of Purchases by Campaign', fontsize=14)
axes[0].set_xlabel('Number of Purchases')
axes[0].set_ylabel('Campaign')

# Bar chart - Unique Buyers by Campaign (Fixed)
sns.barplot(
    data=campaign_stats, 
    x='unique_buyers', 
    y='campaign_purchase', 
    hue='campaign_purchase',      # Fix: assign hue
    palette='magma', 
    legend=False,                 # Fix: remove legend
    ax=axes[1]
)
axes[1].set_title('Unique Buyers by Campaign', fontsize=14)
axes[1].set_xlabel('Unique Buyers')
axes[1].set_ylabel('Campaign')

plt.tight_layout()
plt.show()

# %%
# 3. Key Insights
print("\n" + "="*60)
print("🔍 KEY CAMPAIGN INSIGHTS")
print("="*60)

top_campaign = campaign_stats.iloc[0]
print(f"🏆 Most Successful Campaign : {top_campaign['campaign_purchase']}")
print(f"   • Purchases              : {top_campaign['num_purchases']:,}")
print(f"   • Unique Buyers          : {top_campaign['unique_buyers']:,}")

no_campaign = campaign_stats[campaign_stats['campaign_purchase'] == 'no_campaign'].iloc[0]
print(f"\n📉 No Campaign Period:")
print(f"   • Purchases : {no_campaign['num_purchases']:,}")
print(f"   • Unique Buyers : {no_campaign['unique_buyers']:,}")

print(f"\n📈 Campaign vs Non-Campaign:")
print(f"   Campaigns drove {campaign_stats[campaign_stats['campaign_purchase'] != 'no_campaign']['num_purchases'].sum():,} purchases")
# Out:
# ============================================================
# 🔍 KEY CAMPAIGN INSIGHTS
# ============================================================
# 🏆 Most Successful Campaign : no_campaign
#    • Purchases              : 660
#    • Unique Buyers          : 532
#
# 📉 No Campaign Period:
#    • Purchases : 660
#    • Unique Buyers : 532
#
# 📈 Campaign vs Non-Campaign:
#    Campaigns drove 340 purchases

# %%
print("📈 Campaign vs Normal Period Engagement Analysis (Session Count Based)\n")

# Main Query
query = """
WITH engagement_with_period AS (
    SELECT 
        e.*,
        CASE 
            WHEN e.date_engaged BETWEEN '2022-01-17' AND '2022-01-28' THEN 'winter_sale_2022'
            WHEN e.date_engaged BETWEEN '2022-03-21' AND '2022-03-31' THEN 'spring_special_offer_2022'
            WHEN e.date_engaged BETWEEN '2022-05-20' AND '2022-06-01' THEN 'data_science_summer_campaign_2022'
            WHEN e.date_engaged BETWEEN '2022-07-18' AND '2022-07-29' THEN 'most_wanted_campaign'
            WHEN e.date_engaged = '2022-09-16' THEN 'platform_gamification'
            WHEN e.date_engaged BETWEEN '2022-09-19' AND '2022-09-30' THEN 'data_science_hero_campaign'
            ELSE 'normal_period'
        END AS period_type
    FROM student_engagement e
)
SELECT 
    period_type,
    COUNT(*) AS total_engagement_sessions,                    -- Primary metric: count of engagement_id
    COUNT(DISTINCT student_id) AS unique_students_engaged,
    ROUND(AVG(engagement_quizzes), 2) AS avg_quizzes_attempted,
    ROUND(AVG(engagement_exams), 2) AS avg_exams_attempted,
    ROUND(AVG(engagement_lessons), 2) AS avg_lessons_engaged,
    SUM(engagement_quizzes) AS total_quizzes,
    SUM(engagement_exams) AS total_exams,
    SUM(engagement_lessons) AS total_lessons
FROM engagement_with_period
GROUP BY period_type
ORDER BY 
    CASE WHEN period_type = 'normal_period' THEN 1 ELSE 0 END,
    total_engagement_sessions DESC;
"""

engagement_comparison = pd.read_sql(query, conn)

print("✅ Engagement Comparison Results:")
print(engagement_comparison)
# Out:
# 📈 Campaign vs Normal Period Engagement Analysis (Session Count Based)
#
# ✅ Engagement Comparison Results:
#                          period_type  total_engagement_sessions  \
# 0                   winter_sale_2022                        135
# 1  data_science_summer_campaign_2022                         46
# 2          spring_special_offer_2022                         17
# 3                      normal_period                        802
#
#    unique_students_engaged  avg_quizzes_attempted  avg_exams_attempted  \
# 0                       64                   1.00                 0.36
# 1                       42                   0.48                 0.39
# 2                       11                   1.00                 0.29
# 3                      311                   1.00                 0.25
#
#    avg_lessons_engaged  total_quizzes  total_exams  total_lessons
# 0                 1.00            135           49            135
# 1                 0.98             22           18             45
# 2                 1.00             17            5             17
# 3                 1.00            802          198            798

# %%
# =============================================
# Visualizations
# =============================================

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# 1. Total Engagement Sessions (Main Metric)
sns.barplot(data=engagement_comparison, 
            x='total_engagement_sessions', 
            y='period_type', 
            hue='period_type',
            palette='viridis', 
            legend=False, ax=axes[0,0])
axes[0,0].set_title('Total Engagement Sessions by Period', fontsize=14)
axes[0,0].set_xlabel('Number of Engagement Sessions')

# 2. Unique Students Engaged
sns.barplot(data=engagement_comparison, 
            x='unique_students_engaged', 
            y='period_type', 
            hue='period_type',
            palette='magma',
            legend=False, ax=axes[0,1])
axes[0,1].set_title('Unique Students Engaged')

# 3. Average Activity Breakdown
activity_df = engagement_comparison.melt(
    id_vars=['period_type'],
    value_vars=['avg_quizzes_attempted', 'avg_exams_attempted', 'avg_lessons_engaged'],
    var_name='activity_type',
    value_name='average_count'
)

sns.barplot(data=activity_df, 
            x='average_count', 
            y='period_type', 
            hue='activity_type', 
            palette='Set2', 
            legend=False, ax=axes[1,0])
axes[1,0].set_title('Average Activity Count per Session')

# 4. Total Activities
total_activity = engagement_comparison.melt(
    id_vars=['period_type'],
    value_vars=['total_quizzes', 'total_exams', 'total_lessons'],
    var_name='activity_type',
    value_name='total_count'
)

sns.barplot(data=total_activity, 
            x='total_count', 
            y='period_type', 
            hue='activity_type', 
            palette='Set3', 
            legend=False, ax=axes[1,1])
axes[1,1].set_title('Total Activities Across All Sessions')

plt.tight_layout()
plt.show()

# %%
# =============================================
# Key Insights
# =============================================
print("\n" + "="*70)
print("🔍 KEY INSIGHTS: Campaign Impact on Engagement (Session Count)")
print("="*70)

normal = engagement_comparison[engagement_comparison['period_type'] == 'normal_period'].iloc[0]
campaign_rows = engagement_comparison[engagement_comparison['period_type'] != 'normal_period']

best_campaign = campaign_rows.loc[campaign_rows['total_engagement_sessions'].idxmax()]

print(f"Normal Period:")
print(f"   • Total Sessions          : {normal['total_engagement_sessions']:,}")
print(f"   • Unique Students Engaged : {normal['unique_students_engaged']:,}")

print(f"\nBest Performing Campaign: **{best_campaign['period_type']}**")
print(f"   • Total Sessions          : {best_campaign['total_engagement_sessions']:,}")
print(f"   • Unique Students Engaged : {best_campaign['unique_students_engaged']:,}")

if best_campaign['total_engagement_sessions'] > normal['total_engagement_sessions']:
    print(f"\n✅ Campaigns generated MORE engagement sessions than normal periods!")
else:
    print(f"\n⚠️  Campaigns generated fewer engagement sessions than normal periods.")

print(f"\nTotal engagement sessions during all campaigns combined: {campaign_rows['total_engagement_sessions'].sum():,}")
# Out:
# ======================================================================
# 🔍 KEY INSIGHTS: Campaign Impact on Engagement (Session Count)
# ======================================================================
# Normal Period:
#    • Total Sessions          : 802
#    • Unique Students Engaged : 311
#
# Best Performing Campaign: **winter_sale_2022**
#    • Total Sessions          : 135
#    • Unique Students Engaged : 64
#
# ⚠️  Campaigns generated fewer engagement sessions than normal periods.
#
# Total engagement sessions during all campaigns combined: 198

# %% [markdown]
# **Visualization**: Grouped bar chart showing total engagement sessions by period.

# %% [markdown]
# ## Phase 3: Combining Tables in SQL (Student Journey Analysis)
# ### Goal: Compute key platform KPIs and identify high-level issues.

# %%
# Add useful indexes (run this once)
with tqdm(total=1, desc="Course Analysis") as pbar:
    print("Creating indexes to speed up future queries...")
    
    conn.execute("CREATE INDEX IF NOT EXISTS idx_learning_course_student ON student_learning(course_id, student_id);")
    conn.execute("CREATE INDEX IF NOT EXISTS idx_engagement_student ON student_engagement(student_id);")
    conn.execute("CREATE INDEX IF NOT EXISTS idx_ratings_course ON course_ratings(course_id);")
    
    conn.commit()
    print("✅ Indexes created!")
    pbar.update(1)
# Out:
# Course Analysis: 100%|███████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 21.38it/s]
# Creating indexes to speed up future queries...
# ✅ Indexes created!

# %%
# =============================================
# PHASE 3: Fixed & Faster Student Journey Analysis
# =============================================

print("🔗 Running Fixed Student Journey Analysis...\n")

with tqdm(total=1, desc="Course Analysis") as pbar:
    query = """
    SELECT 
        c.course_title,
        COUNT(DISTINCT p.student_id) AS total_buyers,
        COUNT(DISTINCT l.student_id) AS started_learning,
        COUNT(DISTINCT e.student_id) AS actively_engaged,
        COUNT(DISTINCT r.student_id) AS gave_rating,
        
        ROUND(100.0 * COUNT(DISTINCT l.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS learning_start_rate_pct,
        ROUND(100.0 * COUNT(DISTINCT e.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS engagement_rate_pct,
        ROUND(100.0 * COUNT(DISTINCT r.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS rating_rate_pct
    FROM course_info c
    LEFT JOIN student_purchases p ON 1 = 1
    LEFT JOIN student_learning l ON c.course_id = l.course_id
    LEFT JOIN student_engagement e ON l.student_id = e.student_id
    LEFT JOIN course_ratings r ON c.course_id = r.course_id
    GROUP BY c.course_title
    ORDER BY engagement_rate_pct ASC NULLS LAST;
    """
    
    journey_df = pd.read_sql(query, conn)
    
    print(f"✅ Analysis completed! ({len(journey_df)} courses)")
    
    print("\nTop 10 Courses with Lowest Engagement Rate:")
    print(journey_df[['course_title', 'total_buyers', 'started_learning', 
                      'actively_engaged', 'engagement_rate_pct']].head(10).round(2))
    
    print(f"\nOverall Average Engagement Rate: {journey_df['engagement_rate_pct'].mean():.2f}%")
    print(f"Lowest Engagement Rate : {journey_df['engagement_rate_pct'].min():.2f}%")
    print(f"Highest Engagement Rate : {journey_df['engagement_rate_pct'].max():.2f}%")
    
    pbar.update(1)
# Out:
# 🔗 Running Fixed Student Journey Analysis...
# Course Analysis: 100%|█████████████████████████████████████████████████████████| 1/1 [18:13<00:00, 1093.14s/it]
# ✅ Analysis completed! (46 courses)
#
# Top 10 Courses with Lowest Engagement Rate:
#                                         course_title  total_buyers  \
# 0                              A/B Testing in Python           839
# 1  Convolutional Neural Networks with TensorFlow ...           839
# 2                        Data-Driven Business Growth           839
# 3                          Dates and Times in Python           839
# 4                     Fashion Analytics with Tableau           839
# 5                 Introduction to Business Analytics           839
# 6                          Machine Learning in Excel           839
# 7  Machine Learning with Decision Trees and Rando...           839
# 8          Machine Learning with K-Nearest Neighbors           839
# 9                 Machine Learning with NaÃ¯ve Bayes           839
#
#    started_learning  actively_engaged  engagement_rate_pct
# 0                 1                 0                  0.0
# 1                 2                 0                  0.0
# 2                 0                 0                  0.0
# 3                 0                 0                  0.0
# 4                 0                 0                  0.0
# 5                 0                 0                  0.0
# 6                 0                 0                  0.0
# 7                 0                 0                  0.0
# 8                 0                 0                  0.0
# 9                 0                 0                  0.0
#
# Overall Average Engagement Rate: 0.62%
# Lowest Engagement Rate : 0.00%
# Highest Engagement Rate : 7.87%

# %% [markdown]
# **Opportunity**: Courses with high purchases but low engagement/progress = content or difficulty mismatch.

# %% [markdown]
# ## Phase 4: SQL Subqueries
# ### Goal: Benchmark courses and students against peers.

# %%
# =============================================
# PHASE 4: SQL Subqueries - Benchmarking Courses
# =============================================

print("📊 PHASE 4: Using Subqueries for Benchmarking & Insights\n")

with tqdm(total=1, desc="Course Analysis") as pbar:
    subquery_query = """
    WITH course_metrics AS (
        SELECT 
            c.course_title,
            COUNT(DISTINCT p.student_id) AS total_buyers,
            COUNT(DISTINCT l.student_id) AS started_learning,
            COUNT(DISTINCT e.student_id) AS actively_engaged,
            ROUND(100.0 * COUNT(DISTINCT l.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS learning_start_rate_pct,
            ROUND(100.0 * COUNT(DISTINCT e.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS engagement_rate_pct,
            ROUND(AVG(e.engagement_quizzes), 2) AS avg_quizzes,
            ROUND(AVG(e.engagement_lessons), 2) AS avg_lessons
        FROM course_info c
        LEFT JOIN student_purchases p ON 1 = 1
        LEFT JOIN student_learning l ON c.course_id = l.course_id
        LEFT JOIN student_engagement e ON l.student_id = e.student_id
        GROUP BY c.course_title
    ),
    platform_averages AS (
        SELECT 
            ROUND(AVG(engagement_rate_pct), 2) AS platform_avg_engagement_rate,
            ROUND(AVG(learning_start_rate_pct), 2) AS platform_avg_learning_rate
        FROM course_metrics
    )
    SELECT 
        cm.course_title,
        cm.total_buyers,
        cm.started_learning,
        cm.actively_engaged,
        cm.engagement_rate_pct,
        pa.platform_avg_engagement_rate,
        
        -- Subquery: Compare to platform average
        CASE 
            WHEN cm.engagement_rate_pct < pa.platform_avg_engagement_rate * 0.7 
                THEN 'Significantly Below Average'
            WHEN cm.engagement_rate_pct < pa.platform_avg_engagement_rate * 0.9 
                THEN 'Below Average'
            WHEN cm.engagement_rate_pct > pa.platform_avg_engagement_rate * 1.2 
                THEN 'Well Above Average'
            ELSE 'Around Average'
        END AS performance_vs_platform,
        
        ROUND(cm.engagement_rate_pct - pa.platform_avg_engagement_rate, 2) AS diff_from_platform_avg
        
    FROM course_metrics cm
    CROSS JOIN platform_averages pa
    WHERE cm.total_buyers >= 5
    ORDER BY cm.engagement_rate_pct ASC;
    """
    
    benchmark_df = pd.read_sql(subquery_query, conn)
    
    print(f"✅ Subquery Analysis Completed! ({len(benchmark_df)} courses benchmarked)")
    
    print("\nCourses Significantly Below Platform Average (Biggest Opportunities):")
    below_avg = benchmark_df[benchmark_df['performance_vs_platform'].str.contains('Below', na=False)]
    print(below_avg[['course_title', 'total_buyers', 'engagement_rate_pct', 
                     'platform_avg_engagement_rate', 'performance_vs_platform']].round(2))
    
    print(f"\nPlatform Average Engagement Rate: {benchmark_df['platform_avg_engagement_rate'].iloc[0]:.2f}%")
    pbar.update(1)
# Out:
# 📊 PHASE 4: Using Subqueries for Benchmarking & Insights
# Course Analysis: 100%|███████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.80s/it]
# ✅ Subquery Analysis Completed! (46 courses benchmarked)
#
# Courses Significantly Below Platform Average (Biggest Opportunities):
#                                          course_title  total_buyers  \
# 0                               A/B Testing in Python           839
# 1   Convolutional Neural Networks with TensorFlow ...           839
# 2                         Data-Driven Business Growth           839
# 3                           Dates and Times in Python           839
# 4                      Fashion Analytics with Tableau           839
# 5                  Introduction to Business Analytics           839
# 6                           Machine Learning in Excel           839
# 7   Machine Learning with Decision Trees and Rando...           839
# 8           Machine Learning with K-Nearest Neighbors           839
# 9                  Machine Learning with NaÃ¯ve Bayes           839
# 10   Machine Learning with Ridge and Lasso Regression           839
# 11      Machine Learning with Support Vector Machines           839
# 12                                      SQL + Tableau           839
# 13        Web Scraping and API Fundamentals in Python           839
# 14               AI Applications for Business Success           839
# 15                    Deep Learning with TensorFlow 2           839
# 16               Linear Algebra and Feature Selection           839
# 17           Product Management for AI & Data Science           839
# 18                                 Python for Finance           839
# 19                    SQL for Data Science Interviews           839
# 20                     Credit Risk Modeling in Python           839
# 21                       Customer Analytics in Python           839
# 22        Data Cleaning and Preprocessing with pandas           839
# 23                             SQL + Tableau + Python           839
# 24  Starting a Career in Data Science: Project Por...           839
# 25                   Time Series Analysis with Python           839
# 26                                     Git and GitHub           839
# 27                      Introduction to R Programming           839
# 28                                        Probability           839
# 29                           Advanced Microsoft Excel           839
# 30                                      Data Literacy           839
# 31                      Data Preprocessing with NumPy           839
#
#     engagement_rate_pct  platform_avg_engagement_rate  \
# 0                  0.00                          0.62
# 1                  0.00                          0.62
# 2                  0.00                          0.62
# 3                  0.00                          0.62
# 4                  0.00                          0.62
# 5                  0.00                          0.62
# 6                  0.00                          0.62
# 7                  0.00                          0.62
# 8                  0.00                          0.62
# 9                  0.00                          0.62
# 10                 0.00                          0.62
# 11                 0.00                          0.62
# 12                 0.00                          0.62
# 13                 0.00                          0.62
# 14                 0.12                          0.62
# 15                 0.12                          0.62
# 16                 0.12                          0.62
# 17                 0.12                          0.62
# 18                 0.12                          0.62
# 19                 0.12                          0.62
# 20                 0.24                          0.62
# 21                 0.24                          0.62
# 22                 0.24                          0.62
# 23                 0.24                          0.62
# 24                 0.24                          0.62
# 25                 0.24                          0.62
# 26                 0.36                          0.62
# 27                 0.36                          0.62
# 28                 0.36                          0.62
# 29                 0.48                          0.62
# 30                 0.48                          0.62
# 31                 0.48                          0.62
#
#         performance_vs_platform
# 0   Significantly Below Average
# 1   Significantly Below Average
# 2   Significantly Below Average
# 3   Significantly Below Average
# 4   Significantly Below Average
# 5   Significantly Below Average
# 6   Significantly Below Average
# 7   Significantly Below Average
# 8   Significantly Below Average
# 9   Significantly Below Average
# 10  Significantly Below Average
# 11  Significantly Below Average
# 12  Significantly Below Average
# 13  Significantly Below Average
# 14  Significantly Below Average
# 15  Significantly Below Average
# 16  Significantly Below Average
# 17  Significantly Below Average
# 18  Significantly Below Average
# 19  Significantly Below Average
# 20  Significantly Below Average
# 21  Significantly Below Average
# 22  Significantly Below Average
# 23  Significantly Below Average
# 24  Significantly Below Average
# 25  Significantly Below Average
# 26  Significantly Below Average
# 27  Significantly Below Average
# 28  Significantly Below Average
# 29                Below Average
# 30                Below Average
# 31                Below Average
#
# Platform Average Engagement Rate: 0.62%
# Course Analysis: 100%|███████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.81s/it]

# %%
# Visualization
plt.figure(figsize=(12, 8))
sns.barplot(data=below_avg.head(10), 
            x='engagement_rate_pct', 
            y='course_title', 
            hue='course_title',
            palette='Reds_r',
            legend=False)
plt.axvline(x=benchmark_df['platform_avg_engagement_rate'].iloc[0], color='blue', linestyle='--', label='Platform Average')
plt.title('Courses Significantly Below Platform Average Engagement Rate')
plt.xlabel('Engagement Rate (%)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Phase 5: Window Functions in SQL
# ### Goal: Advanced ranking, trends, and segmentation.

# %%
# =============================================
# PHASE 5: Window Functions in SQL
# =============================================


sns.set(style="whitegrid")
print("📈 PHASE 5: Window Functions - Ranking, Percentiles & Trends\n")

with tqdm(total=1, desc="Course Analysis") as pbar:
    window_query = """
    WITH course_metrics AS (
        SELECT 
            c.course_title,
            COUNT(DISTINCT p.student_id) AS total_buyers,
            COUNT(DISTINCT l.student_id) AS started_learning,
            COUNT(DISTINCT e.student_id) AS actively_engaged,
            ROUND(100.0 * COUNT(DISTINCT l.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS learning_start_rate_pct,
            ROUND(100.0 * COUNT(DISTINCT e.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS engagement_rate_pct,
            ROUND(AVG(e.engagement_quizzes), 2) AS avg_quizzes,
            ROUND(AVG(e.engagement_lessons), 2) AS avg_lessons
        FROM course_info c
        LEFT JOIN student_purchases p ON 1 = 1
        LEFT JOIN student_learning l ON c.course_id = l.course_id
        LEFT JOIN student_engagement e ON l.student_id = e.student_id
        GROUP BY c.course_title
    ),
    ranked_courses AS (
        SELECT 
            course_title,
            total_buyers,
            started_learning,
            actively_engaged,
            engagement_rate_pct,
            -- Window Function 1: Ranking within all courses
            RANK() OVER (ORDER BY engagement_rate_pct DESC) AS engagement_rank,
            -- Window Function 2: Percentile rank
            ROUND(PERCENT_RANK() OVER (ORDER BY engagement_rate_pct) * 100, 2) AS engagement_percentile,
            -- Window Function 3: Difference from previous course (using LAG)
            engagement_rate_pct - LAG(engagement_rate_pct) OVER (ORDER BY engagement_rate_pct DESC) AS diff_from_previous
        FROM course_metrics
        WHERE total_buyers >= 5
    )
    SELECT 
        course_title,
        total_buyers,
        actively_engaged,
        engagement_rate_pct,
        engagement_rank,
        engagement_percentile,
        ROUND(diff_from_previous, 2) AS diff_from_previous_course
    FROM ranked_courses
    ORDER BY engagement_rank;
    """
    
    window_df = pd.read_sql(window_query, conn)
    
    print(f"✅ Window Functions Analysis Completed! ({len(window_df)} courses ranked)")
    
    print("\nTop 10 Best Performing Courses by Engagement Rank:")
    print(window_df[['course_title', 'total_buyers', 'actively_engaged', 
                     'engagement_rate_pct', 'engagement_rank']].head(10).round(2))
    
    print("\nBottom 10 Worst Performing Courses (Highest Priority for Improvement):")
    print(window_df[['course_title', 'total_buyers', 'actively_engaged', 
                     'engagement_rate_pct', 'engagement_rank']].tail(10).round(2))
    pbar.update(1)
# Out:
# 📈 PHASE 5: Window Functions - Ranking, Percentiles & Trends
# Course Analysis: 100%|███████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.43s/it]
# ✅ Window Functions Analysis Completed! (46 courses ranked)
#
# Top 10 Best Performing Courses by Engagement Rank:
#                             course_title  total_buyers  actively_engaged  \
# 0  Introduction to Data and Data Science           839                66
# 1                             Statistics           839                33
# 2                  Introduction to Excel           839                21
# 3                                    SQL           839                20
# 4                Introduction to Jupyter           839                 7
# 5                 Introduction to Python           839                 7
# 6                Introduction to Tableau           839                 7
# 7  Data Analysis with Excel Pivot Tables           839                 6
# 8                          Data Strategy           839                 6
# 9             Python Programmer Bootcamp           839                 6
#
#    engagement_rate_pct  engagement_rank
# 0                 7.87                1
# 1                 3.93                2
# 2                 2.50                3
# 3                 2.38                4
# 4                 0.83                5
# 5                 0.83                5
# 6                 0.83                5
# 7                 0.72                8
# 8                 0.72                8
# 9                 0.72                8
#
# Bottom 10 Worst Performing Courses (Highest Priority for Improvement):
#                                          course_title  total_buyers  \
# 36                     Fashion Analytics with Tableau           839
# 37                 Introduction to Business Analytics           839
# 38                          Machine Learning in Excel           839
# 39  Machine Learning with Decision Trees and Rando...           839
# 40          Machine Learning with K-Nearest Neighbors           839
# 41                 Machine Learning with NaÃ¯ve Bayes           839
# 42   Machine Learning with Ridge and Lasso Regression           839
# 43      Machine Learning with Support Vector Machines           839
# 44                                      SQL + Tableau           839
# 45        Web Scraping and API Fundamentals in Python           839
#
#     actively_engaged  engagement_rate_pct  engagement_rank
# 36                 0                  0.0               33
# 37                 0                  0.0               33
# 38                 0                  0.0               33
# 39                 0                  0.0               33
# 40                 0                  0.0               33
# 41                 0                  0.0               33
# 42                 0                  0.0               33
# 43                 0                  0.0               33
# 44                 0                  0.0               33
# 45                 0                  0.0               33

# %%
# =============================================
# Visualizations
# =============================================

plt.figure(figsize=(14, 8))
top_bottom = pd.concat([window_df.head(8), window_df.tail(8)])

sns.barplot(data=top_bottom, x='engagement_rate_pct', y='course_title', 
            hue=top_bottom['engagement_rank'].apply(lambda x: 'Top' if x <= 8 else 'Bottom'), 
            palette={'Top': 'green', 'Bottom': 'red'})
plt.title('Top 8 vs Bottom 8 Courses by Engagement Rate (Window Functions)')
plt.xlabel('Engagement Rate (%)')
plt.ylabel('')
plt.legend(title='Performance Group')
plt.tight_layout()
plt.show()

# Percentile Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=window_df, x='engagement_percentile', bins=10, kde=True)
plt.title('Distribution of Courses by Engagement Percentile')
plt.xlabel('Engagement Percentile (%)')
plt.ylabel('Number of Courses')
plt.axvline(25, color='red', linestyle='--', label='Bottom 25%')
plt.legend()
plt.show()

# %%
# RANK() — Ranking courses by engagement (Ranking within Category (Top & Bottom courses by engagement))
# PERCENT_RANK() — Showing percentile position (Percentile Analysis – Bottom 25% engagement courses)
# LAG() — Comparing to the previous row (Month-over-Month Trend (using LAG))
# Practical business use: identifying top/bottom performers and gaps

# %% [markdown]
# ## Phase 6: Final Insights & Dashboard

# %%
# =============================================
# PHASE 6: Final Insights & Business Recommendations (Fixed)
# =============================================
print("🎯 PHASE 6: Final Insights & Actionable Recommendations\n")

# ===================================================================
# 1. Platform KPIs (Fixed)
# ===================================================================

kpi_query = """
SELECT 
    (SELECT COUNT(DISTINCT student_id) FROM student_info) AS total_students,
    (SELECT COUNT(DISTINCT course_id) FROM course_info) AS total_courses,
    (SELECT COUNT(*) FROM student_purchases) AS total_purchases,
    (SELECT COUNT(DISTINCT student_id) FROM student_engagement) AS total_engaged_students;
"""

kpis = pd.read_sql(kpi_query, conn).iloc[0]

print("📋 Platform Overview")
print("="*50)
print(f"Total Students          : {kpis['total_students']:,}")
print(f"Total Courses           : {kpis['total_courses']:,}")
print(f"Total Purchases         : {kpis['total_purchases']:,}")
print(f"Total Engaged Students  : {kpis['total_engaged_students']:,}")

# ===================================================================
# 2. Journey Summary
# ===================================================================

journey_summary = pd.read_sql("""
    SELECT 
        ROUND(AVG(engagement_rate_pct), 2) AS avg_engagement_rate,
        MIN(engagement_rate_pct) AS min_engagement_rate,
        COUNT(CASE WHEN engagement_rate_pct < 30 THEN 1 END) AS courses_below_30
    FROM (
        SELECT 
            ROUND(100.0 * COUNT(DISTINCT e.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS engagement_rate_pct
        FROM course_info c
        LEFT JOIN student_purchases p ON 1=1
        LEFT JOIN student_learning l ON c.course_id = l.course_id
        LEFT JOIN student_engagement e ON l.student_id = e.student_id
        GROUP BY c.course_title
    ) sub;
""", conn).iloc[0]

print(f"\nAverage Engagement Rate : {journey_summary['avg_engagement_rate']:.2f}%")
print(f"Lowest Engagement Rate  : {journey_summary['min_engagement_rate']:.2f}%")

# ===================================================================
# 3. Problematic Courses
# ===================================================================

problem_courses = pd.read_sql("""
    SELECT 
        c.course_title,
        COUNT(DISTINCT p.student_id) AS total_buyers,
        COUNT(DISTINCT e.student_id) AS actively_engaged,
        ROUND(100.0 * COUNT(DISTINCT e.student_id) / NULLIF(COUNT(DISTINCT p.student_id), 0), 2) AS engagement_rate_pct
    FROM course_info c
    LEFT JOIN student_purchases p ON 1=1
    LEFT JOIN student_learning l ON c.course_id = l.course_id
    LEFT JOIN student_engagement e ON l.student_id = e.student_id
    GROUP BY c.course_title
    HAVING total_buyers >= 10
    ORDER BY engagement_rate_pct ASC
    LIMIT 5;
""", conn)

print("\n🚨 Top 5 Courses Needing Urgent Attention:")
print(problem_courses[['course_title', 'total_buyers', 'actively_engaged', 'engagement_rate_pct']])

# ===================================================================
# 4. Visualizations (Fixed - No deprecation warning)
# ===================================================================

fig = plt.figure(figsize=(18, 10))

# Top vs Bottom Courses
plt.subplot(1, 2, 1)
top_bottom = pd.concat([journey_df.head(6), journey_df.tail(6)]) if 'journey_df' in globals() else problem_courses

sns.barplot(
    data=top_bottom, 
    x='engagement_rate_pct', 
    y='course_title', 
    hue='course_title',           # Fix for deprecation
    palette='RdYlGn_r',
    legend=False                  # Remove legend since y is already the label
)
plt.title('Top & Bottom Courses by Engagement Rate')
plt.xlabel('Engagement Rate (%)')

# Engagement Rate Distribution
plt.subplot(1, 2, 2)
sns.histplot(data=journey_df if 'journey_df' in globals() else pd.DataFrame(), 
             x='engagement_rate_pct', bins=15, kde=True, color='skyblue')
plt.title('Distribution of Engagement Rates Across Courses')
plt.xlabel('Engagement Rate (%)')
plt.axvline(journey_summary['avg_engagement_rate'], color='red', linestyle='--', label='Average')
plt.legend()

plt.tight_layout()
plt.show()

# ===================================================================
# 5. Final Business Recommendations
# ===================================================================

display(Markdown("### 🎯 **Key Business Recommendations**"))

print("\n1. **Urgent Content Intervention Required**")
print(f"   → Average engagement rate is only {journey_summary['avg_engagement_rate']:.2f}%. This is critically low.")

print("\n2. **Priority Courses for Improvement**")
for _, row in problem_courses.iterrows():
    print(f"   • **{row['course_title']}** — {row['total_buyers']} buyers but only {row['engagement_rate_pct']}% engaged")

print("\n3. **Recommended Actions:**")
print("   • Perform deep content audit on bottom-performing courses")
print("   • Increase interactivity (quizzes, lessons, assignments)")
print("   • Improve initial learner onboarding experience")
print("   • Test re-engagement campaigns for students who purchased but never engaged")
print("   • Consider adding progress tracking and gamification features")

print("\n" + "="*80)
print("✅ PROJECT COMPLETE - All SQL phases successfully demonstrated!")
print("="*80)
# Out:
# 🎯 PHASE 6: Final Insights & Actionable Recommendations
#
# 📋 Platform Overview
# ==================================================
# Total Students          : 1,000
# Total Courses           : 46
# Total Purchases         : 1,000
# Total Engaged Students  : 360
#
# Average Engagement Rate : 0.62%
# Lowest Engagement Rate  : 0.00%
#
# 🚨 Top 5 Courses Needing Urgent Attention:
#                                         course_title  total_buyers  \
# 0                              A/B Testing in Python           839
# 1  Convolutional Neural Networks with TensorFlow ...           839
# 2                        Data-Driven Business Growth           839
# 3                          Dates and Times in Python           839
# 4                     Fashion Analytics with Tableau           839
#
#    actively_engaged  engagement_rate_pct
# 0                 0                  0.0
# 1                 0                  0.0
# 2                 0                  0.0
# 3                 0                  0.0
# 4                 0                  0.0
# ### 🎯 **Key Business Recommendations**
# 1. **Urgent Content Intervention Required**
#    → Average engagement rate is only 0.62%. This is critically low.
#
# 2. **Priority Courses for Improvement**
#    • **A/B Testing in Python** — 839 buyers but only 0.0% engaged
#    • **Convolutional Neural Networks with TensorFlow in Python** — 839 buyers but only 0.0% engaged
#    • **Data-Driven Business Growth** — 839 buyers but only 0.0% engaged
#    • **Dates and Times in Python** — 839 buyers but only 0.0% engaged
#    • **Fashion Analytics with Tableau** — 839 buyers but only 0.0% engaged
#
# 3. **Recommended Actions:**
#    • Perform deep content audit on bottom-performing courses
#    • Increase interactivity (quizzes, lessons, assignments)
#    • Improve initial learner onboarding experience
#    • Test re-engagement campaigns for students who purchased but never engaged
#    • Consider adding progress tracking and gamification features
#
# ================================================================================
# ✅ PROJECT COMPLETE - All SQL phases successfully demonstrated!
# ================================================================================
